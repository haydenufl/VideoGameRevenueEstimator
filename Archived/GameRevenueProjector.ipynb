# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Pandas should be able to read this without prefixing it with 'content', if not try "df = pd.read_csv('content/drive/MyDrive...')
#
#
# ---
#
#
# An issue is not being able to read the data as is. encoding='ISO-8859-1' is required to convert it to UTF-8.

# %%
df = pd.read_csv('drive/MyDrive/CAP4770 - Group 7/Steam-Game-Data.csv',encoding='ISO-8859-1')
# Out:
# /tmp/ipython-input-15-2167694278.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('drive/MyDrive/CAP4770 - Group 7/Steam-Game-Data.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    #                      Title       Release  Price  \
# 0  1  Grand Theft Auto V Legacy  Apr 14, 2015  29.99
# 1  2         Black Myth: Wukong  Aug 19, 2024  59.99
# 2  3                 ELDEN RING  Feb 24, 2022  59.99
# 3  4             Cyberpunk 2077   Dec 9, 2020  59.99
# 4  5      Red Dead Redemption 2   Dec 5, 2019  59.99
#
#                                                 Tags  \
# 0  Action, Adventure, Atmospheric, Automobile Sim...
# 1  3D, Action, Action RPG, Action-Adventure, Adve...
# 2  3D, Action, Action RPG, Atmospheric, Character...
# 3  Action, Action RPG, Adventure, Atmospheric, Ch...
# 4  Action, Adventure, Atmospheric, Beautiful, FPS...
#
#                                        Publishers          Developers  \
# 0                                  Rockstar Games      Rockstar North
# 1                                    Game Science        Game Science
# 2  Bandai Namco Entertainment, FromSoftware, Inc.  FromSoftware, Inc.
# 3                                  CD PROJEKT RED      CD PROJEKT RED
# 4                                  Rockstar Games      Rockstar Games
#
#    Followers  Reviews  Score       Net Revenue
# 0  3384745.0  1825534      9  1,000,000,000.00
# 1  1370722.0   838856     10    960,000,000.00
# 2  1085962.0   770087      9    890,000,000.00
# 3  1492746.0   753788      9    870,000,000.00
# 4   876870.0   685893      9    790,000,000.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81539 entries, 0 to 81538
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #            81539 non-null  int64
#  1   Title        81500 non-null  object
#  2   Release      81470 non-null  object
#  3   Price        81539 non-null  float64
#  4   Tags         81534 non-null  object
#  5   Publishers   81326 non-null  object
#  6   Developers   81466 non-null  object
#  7   Followers    80105 non-null  float64
#  8   Reviews      81539 non-null  int64
#  9   Score        81539 non-null  int64
#  10  Net Revenue  81539 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 6.8+ MB

# %%
df.describe()
# Out:
#                  #         Price     Followers       Reviews         Score
# count  81539.00000  81539.000000  8.010500e+04  8.153900e+04  81539.000000
# mean   36914.19051      9.475550  3.912187e+03  1.124184e+03      4.666405
# std    18809.84631     15.582815  4.139094e+04  1.602593e+04      3.799003
# min        1.00000      0.500000  1.000000e+00  1.000000e+00      0.000000
# 25%    20385.50000      2.990000  4.200000e+01  4.000000e+00      0.000000
# 50%    40770.00000      5.990000  1.470000e+02  1.700000e+01      6.000000
# 75%    56280.00000     10.990000  7.800000e+02  8.700000e+01      8.000000
# max    59320.00000    999.980000  8.227351e+06  1.825534e+06     10.000000
